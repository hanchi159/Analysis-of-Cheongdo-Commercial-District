# %%
import pandas as pd

# %%
data = pd.read_csv("소상공인시장진흥공단_상가(상권)정보_경북_202112.csv", encoding='utf-8')
# Out:
# C:\Users\hanch\anaconda3\envs\datascience\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (35) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data
# Out:
#           상가업소번호      상호명    지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  상권업종중분류명  \
# 0       17174047    사대부찜닭  송정형곡점         Q       음식       Q05    닭/오리요리
# 1       17174044     단골손님    사곡점         Q       음식       Q01        한식
# 2       21683338     안전용품    NaN         D       소매       D25     기타판매업
# 3       20917006  상주대궐터곶감    NaN         D       소매       D01   음/식료품소매
# 4       17174460   시장실내포차    NaN         Q       음식       Q09      유흥주점
# ...          ...      ...    ...       ...      ...       ...       ...
# 129830  17923101   강아지미용실    NaN         D       소매       D09  애견/애완/동물
# 129831  17945450    진선헤어샵    NaN         F    생활서비스       F01   이/미용/건강
# 129832  17955973  므므흐스연구소    NaN         Q       음식       Q07     패스트푸드
# 129833  17953806       주단    NaN         D       소매       D05      의복의류
# 129834  17948541    하나컨설팅    NaN         F    생활서비스       F13    기타서비스업
#
#        상권업종소분류코드   상권업종소분류명 표준산업분류코드  ...                     건물관리번호    건물명  \
# ...

# %%
set(data["시군구명"])
# Out:
# {'경산시',
#  '경주시',
#  '고령군',
#  '구미시',
#  '군위군',
#  '김천시',
#  '문경시',
#  '봉화군',
#  '상주시',
#  '성주군',
#  '안동시',
#  '영덕군',
#  '영양군',
#  '영주시',
#  '영천시',
#  '예천군',
#  '울릉군',
#  '울진군',
#  '의성군',
#  '청도군',
#  '청송군',
#  '칠곡군',
#  '포항시 남구',
#  '포항시 북구'}

# %%
chengdo = data[data["시군구명"] == "청도군"]
len(chengdo)
cities = []
cafe_counts= []
for i in set(data["시군구명"]):
    city = data[data["시군구명"] == i]
    city_cafe = city[city["상권업종중분류명"] == "커피점/카페"]
    print(i, ":", len(city_cafe))
# Out:
# 문경시 : 170
# 군위군 : 56
# 영양군 : 22
# 울릉군 : 26
# 고령군 : 53
# 영덕군 : 100
# 경주시 : 847
# 안동시 : 382
# 성주군 : 138
# 포항시 북구 : 626
# 경산시 : 563
# 영천시 : 193
# 칠곡군 : 223
# 봉화군 : 59
# 포항시 남구 : 584
# 청도군 : 146
# 울진군 : 132
# 영주시 : 186
# 의성군 : 99
# 구미시 : 734
# 청송군 : 87
# 상주시 : 184
# 김천시 : 234
# 예천군 : 69

# %%
chengdo
# Out:
#           상가업소번호      상호명    지점명 상권업종대분류코드  상권업종대분류명 상권업종중분류코드  상권업종중분류명  \
# 20      23010778    이서황토탕    NaN         F     생활서비스       F09  대중목욕탕/휴게
# 130     28506977  청도돌고래펜션    NaN         O        숙박       O03  캠프/별장/펜션
# 162     15191538       둥지    NaN         Q        음식       Q15        부페
# 163     23251759       CU  청도화양점         D        소매       D03     종합소매점
# 191     20844507  산골노래연습장    NaN         N  관광/여가/오락       N02  무도/유흥/가무
# ...          ...      ...    ...       ...       ...       ...       ...
# 129567  17919045     포유카페    NaN         Q        음식       Q12    커피점/카페
# 129709  17950185        퀸    NaN         D        소매       D05      의복의류
# 129733  17918497  오감즈베이커리    NaN         Q        음식       Q08   제과제빵떡케익
# 129754  17913647    오렌지다방    NaN         Q        음식       Q12    커피점/카페
# 129817  17922895     이지수학    NaN         R     학문/교육       R09      학원기타
#
#        상권업종소분류코드     상권업종소분류명 표준산업분류코드  ...                     건물관리번호  건물명  \
# ...

# %%
cities = ['칠곡군','청도군','성주군','울진군','영덕군','의성군','청송군','예천군','봉화군','군위군','고령군','울릉군','영양군']
cafe_counts = [53,99,138,87,26,100,69,59,132,223,56,146,22]
cafe_counts.sort(reverse=True)
cafe_counts
# Out:
# [223, 146, 138, 132, 100, 99, 87, 69, 59, 56, 53, 26, 22]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import platform

from matplotlib import font_manager, rc
# %matplotlib inline

# %%
path = "c:/Windows/Fonts/malgun.ttf"
if platform.system() == 'Darwin':
    font_name = 'Apple SD Gothic Neo'
    rc('font', family='Apple SD Gothic Neo')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    font_name = font_manager.FontProperties(fname="/usr/share/fonts/nanumfont/NanumGothic.ttf")
    rc('font', family="NanumGothic")

# %%
plt.figure(figsize=(12,12))
plt.title("경상북도 군 별 카페수", fontdict={"fontsize" : 20})
sns.barplot(x=cities,y=cafe_counts)
#plt.savefig("Gyeongsangbukdo_coffee_barplot_20220302.png")
plt.show()

# %%
df_chengdo_coffee = chengdo[chengdo["상권업종중분류명"] == "커피점/카페"]
len(df_chengdo_coffee)
# Out:
# 146

# %%
df_chengdo_coffee_01 = df_chengdo_coffee[df_chengdo_coffee["도로명주소"].str.contains("화양읍")]
df_chengdo_coffee_01.index = range(len(df_chengdo_coffee_01))
df_chengdo_coffee_01
# Out:
#       상가업소번호      상호명      지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 0   20331309     구름다방      NaN         Q       음식       Q12   커피점/카페
# 1   16606182       덕남      NaN         Q       음식       Q12   커피점/카페
# 2   16607168       다뷰      NaN         Q       음식       Q12   커피점/카페
# 3   23469846     스타벅스      NaN         Q       음식       Q12   커피점/카페
# 4   16712836       카페    시고르앤틱         Q       음식       Q12   커피점/카페
# 5   23386788     화양다방      NaN         Q       음식       Q12   커피점/카페
# 6   25633747    오부실까페      NaN         Q       음식       Q12   커피점/카페
# 7   20399547      꽃자리      NaN         Q       음식       Q12   커피점/카페
# 8   23417648  청개구리이야기      NaN         Q       음식       Q12   커피점/카페
# 9   17017214      화담채      NaN         Q       음식       Q12   커피점/카페
# 10  12625977   크레모나커피      NaN         Q       음식       Q12   커피점/카페
# 11  11967710  용암갤러리카페      NaN         Q       음식       Q12   커피점/카페
# 12  11982602   카페선한이웃      NaN         Q       음식       Q12   커피점/카페
# ...

# %%
len(df_chengdo_coffee_01)
# Out:
# 33

# %%
chengdo_cafe = chengdo[chengdo["상권업종중분류명"] == "커피점/카페"]

chengdo_cafe
# Out:
#           상가업소번호    상호명           지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 957     20558235   다강산방           NaN         Q       음식       Q12   커피점/카페
# 2214    20477262   카페리오         리코청도점         Q       음식       Q12   커피점/카페
# 3691    20430927   동영다방           NaN         Q       음식       Q12   커피점/카페
# 5138    16117229   서구커피  청도새마을휴게소부산방면         Q       음식       Q12   커피점/카페
# 5222    16117118   다트나인  청도새마을휴게소부산방면         Q       음식       Q12   커피점/카페
# ...          ...    ...           ...       ...      ...       ...      ...
# 126532  17879908   맛또로롱           NaN         Q       음식       Q12   커피점/카페
# 126688  17851486     카페         아-리-아         Q       음식       Q12   커피점/카페
# 129540  17916872     카페           오감즈         Q       음식       Q12   커피점/카페
# 129567  17919045   포유카페           NaN         Q       음식       Q12   커피점/카페
# 129754  17913647  오렌지다방           NaN         Q       음식       Q12   커피점/카페
#
# ...

# %%
long = []
for i in set(chengdo_cafe["경도"]):
    long.append(i)
lati = []
for i in set(chengdo_cafe["위도"]):
    lati.append(i)
long
# Out:
# [128.747881989727,
#  128.742283672602,
#  128.892517126393,
#  128.739453067483,
#  128.746440275456,
#  128.61701009597,
#  128.764427192842,
#  128.858096875404,
#  128.72176524841,
#  128.56461744959,
#  128.667391714649,
#  128.64936621334,
#  128.690914741134,
#  128.741673464362,
#  128.615802207968,
#  128.619209315254,
#  128.769131551715,
#  128.717675392598,
#  128.715908778385,
#  128.745078754589,
#  128.671922476994,
#  128.563170472481,
#  128.770941649268,
#  128.822780939151,
#  128.74609005107,
#  128.737296555332,
#  128.696878040992,
#  128.742255294142,
#  128.614034257845,
#  128.702866553087,
#  128.559350829888,
#  128.766991332135,
#  128.913914435388,
#  128.742891258708,
#  128.617452590876,
#  128.686767838503,
#  128.672761883101,
#  128.746962682487,
#  128.687946189735,
#  128.619915838458,
#  128.572032032969,
#  128.580658870084,
#  128.769906071354,
#  128.66698459239,
#  128.744650650955,
#  129.002653659325,
#  129.002605767198,
# ...

# %%
pip install folium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge folium
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium

m = folium.Map(location=[35.632628,128.755592], zoom_start=11)

# %%
for i in long:
    print(i)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
for i in range(len(long)):
    folium.Marker([lati[i],long[i]],
              popup="청도 카페",
              tooltip="청도 카페").add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
from folium.plugins import MarkerCluster

m = folium.Map(location=[35.632628,128.755592], zoom_start=11)

marker_cluster = MarkerCluster().add_to(m)

for i in range(len(long)):
    folium.Marker([lati[i], long[i]], icon = folium.Icon(color="green")).add_to(marker_cluster)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
